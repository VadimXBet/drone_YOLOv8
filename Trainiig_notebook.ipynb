# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Если дальше вознинут какие-то ошибки, то можно выполнить `!pip install zip` или `!pip install rar`

# %%
# !unzip -q /content/drive/MyDrive/drone_dataset.zip

# %%
# !git clone https://github.com/VadimXBet/drone_YOLOv8.git
# %cd drone_YOLOv8

# !mv /content/content/drone_dataset /content/drone_YOLOv8

# !unrar x /content/drive/MyDrive/solo_2.rar
# !mv /content/drone_YOLOv8/solo_2 /content/drone_YOLOv8/ultralytics/data
# !rm /content/drone_YOLOv8/ultralytics/data/solo_2/*.json

# %% [markdown]
# Далее нужно внести какие-либо измененния в /content/drone_YOLOv8/drone_dataset/data.yaml

# %%
# !python3 training.py
